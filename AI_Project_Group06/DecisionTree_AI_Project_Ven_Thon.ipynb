# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn import tree
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
import graphviz
from sklearn import datasets
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data.csv', sep=';')
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
#Show shap of data
print("Shap of Dataset", df.shape)
# Out:
# Shap of Dataset (4424, 37)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
#Map categorical target values to numerical values
df['Target'] = df['Target'].map({
    'Dropout': 0,
    'Enrolled': 1,
    'Graduate': 2
})
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %%
df["Target"].unique()
# Out:
# array([0, 2, 1])

# %%
#load the dataset and extract independent and dependent variables
#Separate features (X) and target (y)
x = df.iloc[:, :-1].values #take every row before',' (-1): except the last column, iloc=integer-location
y = df['Target'].values
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
# Scale all values in the Course columns:
column_to_scale = ['Course', 'Previous qualification (grade)', 'Admission grade']
X = df[column_to_scale]

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data
scaled_X = scaler.fit_transform(X)

# Update the 'Course' column in the original DataFrame with scaled values
df[column_to_scale] = scaled_X

# Print the updated DataFrame
df
# Out:
#       Marital status  Application mode  Application order    Course  \
# 0                  1                17                  5 -4.209520
# 1                  1                15                  1  0.192580
# 2                  1                 1                  5  0.103404
# 3                  1                17                  2  0.444115
# 4                  2                39                  1 -0.408389
# ...              ...               ...                ...       ...
# 4419               1                 1                  6  0.444115
# 4420               1                 1                  2  0.444115
# 4421               1                 1                  1  0.311805
# 4422               1                 1                  1  0.140722
# 4423               1                10                  1  0.444115
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %%
#Seperating Target varible
# X = df.values[:, 1:5]
# Y = df.values[:,0]

# X=df.drop('Target', axis=1)
# Y=df['Target']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

#Splitting Dataset into Test and Train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

#Function to perform training with Entropy
clf_entropy = DecisionTreeClassifier(criterion= "entropy",
                                     random_state=0,
                                     max_depth=3,
                                     min_samples_leaf=5)
clf_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=0)

# %%
#Test to find Accuracy data
clf_entropy.score(X_test,y_test)
# Out:
# 0.5378531073446328

# %%
fig = plt.figure(figsize=(15,10))
_=tree.plot_tree(clf_entropy,
                 feature_names=X_train.columns.to_list(),
                filled=True)
